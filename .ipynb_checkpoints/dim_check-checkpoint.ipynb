# %%
from pathlib import Path
import torch
import cv2
from typing import List

# %%
sap_path = Path("/home/stellasu/scratch/stellasu/sapien_poses/QVID/00000284.pt")
mp_path = Path("/home/stellasu/scratch/stellasu/poses/QVID/00000284.pt")

# %%
sap_ten = torch.load(sap_path, map_location="cpu")
mp_ten = torch.load(mp_path, map_location="cpu")

# %%
# sap_ten["bboxes"]
# sap_ten["bbox_scores"]
sap_ten["keypoints"]
# sap_ten["keypoints_visible"]
sap_ten["keypoint_scores"]
sap_ten["total_frames"]
sap_ten["video_path"]
# Out:
# '/orcd/compute/ppliang/001/long_video_datasets/short_video/QVID/videos/00000284.mp4'

# %%
merged_tensor = torch.cat([sap_ten["keypoints"], sap_ten["keypoint_scores"].unsqueeze(-1)], dim=-1)
merged_tensor = merged_tensor.flatten(start_dim=1)
print(merged_tensor.shape)
# Out:
# torch.Size([149, 798])

# %% [markdown]
# ## Test Sampling

# %%
test = torch.load("/home/stellasu/scratch/stellasu/poses/QVID/00000284.perframe_fps1.00_max16.pt", map_location="cpu")
# test = torch.load("/home/stellasu/scratch/stellasu/poses/QVID/00000284.pt", map_location="cpu")
print("Pose Feat Min/Max/Mean:", test.min().item(), test.max().item(), test.mean().item())
# test2 = torch.load("/home/stellasu/scratch/stellasu/poses/QVID/00000284.perframe_fps8.00_max64.pt", map_location="cpu")
# Out:
# Pose Feat Min/Max/Mean: -1.5577032566070557 3.579087018966675 0.31219083070755005

# %%
# test = torch.load("/home/stellasu/scratch/stellasu/sapien_poses/HMDB51/eat/CastAway1_eat_u_nm_np1_fr_med_23.perframe_fps1.00_max16.pt", map_location="cpu")

print("Pose Feat Min/Max/Mean:", test.min().item(), test.max().item(), test.mean().item())
# Out:
# Pose Feat Min/Max/Mean: 0.0 253.14186096191406 46.63469696044922

# %%
test = torch.load("/home/stellasu/scratch/stellasu/sapien_poses/QVID/00000284.pt", map_location="cpu")
# print(test["total_frames"])
# print(test["keypoints"].shape)
# len(test["keypoints"])

keys = test["keypoints"]
scores = test["keypoint_scores"]

print("Pose Feat Min/Max/Mean:", keys.min().item(), keys.max().item(), keys.mean().item())
# Out:
# Pose Feat Min/Max/Mean: -94.80706787109375 652.327392578125 135.8238067626953

# %%
for i, frame in enumerate(keys):
    if frame.min() < 0:
        print(frame.min())
        print(test["bbox_scores"][i])
        print(test["bboxes"][i])
        print(frame)
        # print(test["keypoints_visible"][i])
# Out:
# tensor(-93.3690)
# tensor([1., 0.])
# tensor([[ 71.2263,  23.4567, 542.8501, 359.5192],
#         [  0.0000,   0.0000,   0.0000,   0.0000]])
# tensor([[[326.9429, 159.8508],
#          [355.3179, 119.7792],
#          [294.5093, 118.5728],
#          [388.2295, 138.0688],
#          [260.0191, 141.4139],
#          [436.1928, 292.1261],
#          [162.8325, 294.3123],
#          [324.6838, 165.9607],
#          [328.9909, 166.1240],
#          [488.0005, 343.4451],
#          [ 21.1693, 384.0255],
#          [325.2346, 163.8347],
#          [328.9529, 164.1615],
#          [330.3829, 157.7022],
#          [322.7343, 157.9422],
#          [332.0659, 157.6723],
#          [320.8939, 157.5201],
#          [333.5681, 177.0841],
#          [327.9992, 172.3658],
#          [323.3564, 184.9560],
#          [318.3763, 177.3100],
#          [324.8911, 172.1821],
#          [328.5138, 184.9907],
#          [266.9222, 127.1053],
#          [265.1578, 138.9161],
#          [265.4514, 151.8367],
#          [269.5905, 168.8297],
#          [276.0296, 183.1529],
#          [287.8607, 197.6674],
#          [297.5323, 207.3425],
#          [310.5494, 214.2819],
#          [323.7937, 215.7361],
#          [338.0009, 214.0027],
#          [351.0273, 206.9843],
#          [361.9107, 197.5620],
#          [374.7799, 181.6920],
#          [380.4371, 168.6552],
#          [383.6138, 152.7757],
#          [382.7171, 136.6574],
#          [381.1597, 125.6036],
#          [284.3120, 114.4429],
#          [288.7556, 114.1922],
#          [293.3705, 114.2818],
#          [298.2140, 114.4791],
#          [304.9132, 115.2769],
#          [344.8651, 116.7381],
#          [351.4194, 115.8121],
#          [356.4785, 115.5472],
#          [361.4177, 115.4224],
#          [366.1762, 115.7144],
#          [328.7325, 122.9266],
#          [327.4865, 129.0596],
#          [327.0095, 149.6424],
#          [326.9513, 158.6264],
#          [322.7286, 166.8433],
#          [324.4981, 167.2066],
#          [326.6960, 167.7696],
#          [328.7825, 167.1599],
#          [330.4105, 166.8309],
#          [289.3895, 118.5791],
#          [293.3612, 118.2375],
#          [297.2504, 118.5185],
#          [302.4367, 119.9742],
#          [297.9744, 119.9050],
#          [293.6329, 119.4529],
#          [347.1660, 121.3113],
#          [352.2194, 119.9195],
#          [356.3915, 119.5314],
#          [360.5998, 119.8506],
#          [355.9660, 120.7118],
#          [351.3968, 121.2463],
#          [314.0916, 182.5387],
#          [319.6202, 179.8234],
#          [324.5641, 178.5671],
#          [326.2562, 178.4887],
#          [327.9555, 178.5178],
#          [332.4743, 179.6543],
#          [337.1821, 182.1896],
#          [333.7042, 183.8928],
#          [329.6012, 185.2300],
#          [325.9988, 185.7725],
#          [322.2739, 185.3435],
#          [317.9018, 184.0877],
#          [314.9221, 182.4758],
#          [321.2701, 181.1206],
#          [326.1720, 180.8975],
#          [330.8128, 181.0165],
#          [336.4885, 182.1980],
#          [330.9294, 182.4029],
#          [326.0893, 182.8487],
#          [321.0243, 182.5274],
#          [487.2868, 339.1321],
#          [488.0027, 296.9022],
#          [483.8425, 240.6541],
#          [478.0450, 225.7798],
#          [463.6043, 182.8770],
#          [474.1718, 220.0957],
#          [458.0675, 176.0670],
#          [439.3358, 142.5893],
#          [431.7755, 130.1329],
#          [460.6243, 223.6972],
#          [444.6444, 179.5324],
#          [424.7866, 143.1174],
#          [415.1014, 129.1070],
#          [437.9288, 239.9205],
#          [416.6319, 211.2425],
#          [401.3540, 163.2680],
#          [395.7081, 153.0242],
#          [412.8755, 255.5926],
#          [401.7078, 224.8056],
#          [400.9421, 221.6539],
#          [401.3954, 221.3180],
#          [325.6286, 173.2212],
#          [327.3016, 176.3510],
#          [ 21.1452, -93.3690],
#          [399.9359, 235.7317],
#          [330.0900, 174.7123],
#          [325.2609, 172.7115],
#          [326.4956, 173.6284],
#          [327.0836, 174.9554],
#          [327.9574, 176.2977],
#          [324.7419, 174.3229],
#          [325.6309, 175.1154],
#          [327.3356, 177.6398],
#          [328.3545, 179.6841],
#          [325.3469, 176.4732],
#          [326.0444, 177.5970],
#          [328.0653, 180.3318],
#          [328.7795, 182.1281],
#          [325.9369, 177.9379],
#          [327.3078, 179.4959],
#          [328.7825, 181.9902],
#          [329.6335, 182.9760]],
#
#         [[  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000]]])
# tensor(-94.8071)
# tensor([1., 0.])
# tensor([[ 68.6881,  21.9322, 552.0389, 359.8942],
#         [  0.0000,   0.0000,   0.0000,   0.0000]])
# tensor([[[321.7642, 159.0196],
#          [351.5203, 118.3595],
#          [290.4568, 116.2403],
#          [385.6009, 142.8915],
#          [256.3183, 139.3045],
#          [445.2108, 291.1886],
#          [162.0020, 294.4439],
#          [319.6772, 164.8597],
#          [323.6738, 164.8756],
#          [503.2313, 340.6904],
#          [321.5142, 168.5082],
#          [319.6414, 163.2422],
#          [323.8865, 163.2795],
#          [325.6719, 156.3705],
#          [317.0106, 156.5200],
#          [327.1763, 155.7321],
#          [315.0590, 156.6531],
#          [329.0529, 175.7235],
#          [323.1911, 170.8316],
#          [317.9447, 184.4388],
#          [313.4010, 175.7124],
#          [319.5533, 171.1270],
#          [324.2775, 184.3804],
#          [263.2943, 124.5103],
#          [260.9760, 137.1450],
#          [260.9465, 150.6038],
#          [265.1008, 167.4929],
#          [272.9220, 183.1346],
#          [283.0841, 197.1205],
#          [293.4695, 207.3290],
#          [306.6367, 215.2237],
#          [319.5855, 217.1597],
#          [333.0909, 215.6041],
#          [346.6124, 208.4460],
#          [357.4492, 198.6970],
#          [370.1959, 183.8719],
#          [377.1906, 169.9479],
#          [381.8605, 152.6080],
#          [381.7906, 138.8130],
#          [379.3792, 126.7970],
#          [279.9752, 111.9783],
#          [284.4321, 111.8045],
#          [288.9218, 111.8847],
#          [293.8820, 112.2529],
#          [300.6489, 113.4519],
#          [341.5246, 115.2070],
#          [347.9601, 114.4132],
#          [352.9250, 114.1825],
#          [357.8267, 114.1331],
#          [362.3529, 114.4844],
#          [322.6742, 121.1140],
#          [322.1100, 127.7146],
#          [321.8652, 150.0762],
#          [321.7412, 157.7513],
#          [317.5506, 165.3149],
#          [319.3999, 165.6018],
#          [321.5838, 166.1067],
#          [323.7351, 165.5724],
#          [325.5568, 165.2474],
#          [285.2625, 116.0409],
#          [289.3044, 115.8630],
#          [293.3170, 116.2904],
#          [298.4574, 117.9058],
#          [294.0664, 117.6611],
#          [289.6783, 117.0192],
#          [343.8051, 119.8117],
#          [348.6043, 118.4906],
#          [352.6027, 118.1247],
#          [356.6712, 118.4686],
#          [352.2390, 119.2680],
#          [347.9408, 119.7763],
#          [308.6102, 181.6369],
#          [314.1961, 178.4880],
#          [319.5924, 176.7743],
#          [321.4094, 176.6071],
#          [323.1708, 176.7415],
#          [328.4741, 178.3145],
#          [333.8058, 181.3582],
#          [329.8286, 183.6509],
#          [325.0898, 185.6015],
#          [321.2405, 186.3339],
#          [317.2744, 185.6669],
#          [312.4391, 183.8256],
#          [309.4059, 181.5595],
#          [316.1112, 180.1618],
#          [321.3667, 179.7615],
#          [326.4763, 180.0625],
#          [333.0891, 181.3007],
#          [326.5637, 181.8649],
#          [321.3248, 182.4407],
#          [315.9335, 181.9659],
#          [503.0611, 335.6075],
#          [513.6965, 294.0034],
#          [524.3510, 244.3982],
#          [521.9598, 222.8188],
#          [521.3463, 189.2486],
#          [518.7110, 217.0828],
#          [515.3831, 174.5596],
#          [515.0434, 141.2828],
#          [513.3535, 126.0979],
#          [498.2948, 217.1178],
#          [493.5999, 174.7162],
#          [482.9355, 137.9591],
#          [476.9050, 118.9954],
#          [468.1445, 229.3374],
#          [453.9500, 198.4494],
#          [454.3364, 192.8185],
#          [441.6834, 139.1213],
#          [451.4458, 240.4667],
#          [444.6047, 215.3408],
#          [444.5676, 214.9452],
#          [445.8038, 217.1004],
#          [320.6962, 171.6778],
#          [322.3744, 174.8240],
#          [321.9026, 164.9012],
#          [284.8753, -94.8071],
#          [322.5326, 163.6572],
#          [321.6330, 171.8244],
#          [322.8551, 172.4424],
#          [323.3562, 173.9706],
#          [324.1965, 175.5008],
#          [321.2500, 173.1468],
#          [322.2493, 173.6219],
#          [323.8803, 176.2462],
#          [324.9242, 179.0801],
#          [322.0437, 174.9754],
#          [323.0660, 175.8368],
#          [324.9091, 178.8029],
#          [325.9499, 181.8612],
#          [322.9618, 176.6191],
#          [324.6891, 178.4238],
#          [325.5189, 181.1498],
#          [326.7556, 182.7906]],
#
#         [[  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000]]])
# tensor(-81.8202)
# tensor([1., 0.])
# tensor([[ 69.8220,  23.7487, 555.1177, 359.6866],
#         [  0.0000,   0.0000,   0.0000,   0.0000]])
# tensor([[[323.8445, 159.7987],
#          [352.7142, 119.4992],
#          [292.9702, 117.5048],
#          [386.0520, 144.4507],
#          [257.9428, 140.7575],
#          [457.2408, 292.1764],
#          [161.9304, 296.9076],
#          [321.6369, 166.7318],
#          [325.6686, 166.8100],
#          [508.2796, 343.4102],
#          [185.5462, 346.2679],
#          [321.6776, 164.5815],
#          [325.8708, 164.8786],
#          [327.1984, 157.9650],
#          [320.0104, 157.9930],
#          [328.8109, 157.7618],
#          [317.7264, 158.3091],
#          [330.9044, 178.4409],
#          [324.8252, 172.9900],
#          [320.0410, 186.3454],
#          [314.9517, 178.2768],
#          [321.1748, 172.8052],
#          [325.3833, 186.4123],
#          [265.0371, 126.0430],
#          [262.6965, 138.5965],
#          [262.7799, 151.9636],
#          [266.9080, 168.8908],
#          [274.1723, 184.0934],
#          [284.8484, 198.5034],
#          [295.2293, 208.5007],
#          [308.1452, 216.2852],
#          [321.3877, 218.4615],
#          [334.7655, 216.8119],
#          [347.5421, 209.8314],
#          [358.5833, 199.7906],
#          [370.2594, 185.4969],
#          [377.4421, 171.6033],
#          [382.0970, 153.8712],
#          [382.0806, 139.6620],
#          [380.0914, 127.8892],
#          [282.2441, 113.1760],
#          [286.9464, 113.0827],
#          [291.6360, 113.1490],
#          [296.8186, 113.4779],
#          [303.5570, 114.5274],
#          [342.4397, 116.3257],
#          [349.0381, 115.5695],
#          [354.0846, 115.3993],
#          [358.9500, 115.3765],
#          [363.5627, 115.6985],
#          [325.9366, 122.6837],
#          [324.6756, 128.6058],
#          [324.0514, 149.1822],
#          [323.8648, 158.8969],
#          [319.6202, 167.6259],
#          [321.4182, 168.0464],
#          [323.5529, 168.7576],
#          [325.6853, 168.0529],
#          [327.3954, 167.6411],
#          [287.6450, 117.3736],
#          [291.7842, 117.1789],
#          [295.8741, 117.5500],
#          [301.1608, 119.1382],
#          [296.6874, 118.9792],
#          [292.1700, 118.3467],
#          [344.9110, 120.8864],
#          [349.7928, 119.5887],
#          [353.7329, 119.3418],
#          [357.8536, 119.6148],
#          [353.2377, 120.5005],
#          [349.1203, 120.8662],
#          [310.6931, 183.5026],
#          [316.1789, 180.9692],
#          [321.4292, 179.8604],
#          [323.1453, 179.8179],
#          [324.8222, 179.8349],
#          [329.6630, 180.8503],
#          [334.7814, 183.2616],
#          [330.8592, 185.2088],
#          [326.3914, 186.7910],
#          [322.7195, 187.5415],
#          [318.9575, 186.8518],
#          [314.4380, 185.3682],
#          [311.4776, 183.4880],
#          [317.9362, 182.3823],
#          [322.9971, 182.2747],
#          [327.8001, 182.2999],
#          [333.9303, 183.3151],
#          [327.8953, 183.7446],
#          [322.8701, 184.2997],
#          [317.6815, 183.8498],
#          [508.4249, 338.4882],
#          [518.7908, 297.1052],
#          [530.3602, 247.7327],
#          [528.3704, 224.5952],
#          [534.4253, 192.3162],
#          [525.8934, 218.5738],
#          [534.6064, 177.3160],
#          [541.0271, 143.0244],
#          [544.1851, 126.3908],
#          [502.6158, 218.8826],
#          [497.5573, 175.5115],
#          [488.3362, 138.4849],
#          [483.3298, 119.4017],
#          [471.6859, 230.6830],
#          [457.2663, 199.2016],
#          [457.2694, 194.1061],
#          [442.8582, 140.6569],
#          [455.4835, 240.3427],
#          [446.4006, 218.5560],
#          [446.4429, 218.8368],
#          [447.6440, 221.4274],
#          [322.3045, 173.5426],
#          [323.5745, 176.2787],
#          [324.8408, 171.1521],
#          [290.9584, -81.8202],
#          [325.3089, 169.3813],
#          [322.7940, 173.3402],
#          [323.9398, 174.1991],
#          [324.4084, 175.3701],
#          [325.2859, 176.4754],
#          [322.0634, 174.7660],
#          [322.9265, 175.6193],
#          [324.4433, 177.9297],
#          [325.4831, 179.9268],
#          [322.5337, 176.6353],
#          [323.3156, 177.8398],
#          [325.0525, 180.5557],
#          [325.8636, 182.3667],
#          [323.0543, 177.8835],
#          [324.5790, 179.5866],
#          [325.3570, 182.1134],
#          [326.4952, 183.1774]],
#
#         [[  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000],
#          [  0.0000,   0.0000]]])

# %%
data = torch.load("/home/stellasu/scratch/stellasu/sapien_poses/QVID/00000284.pt", map_location="cpu")
video_path = "/home/stellasu/scratch/stellasu/long_video_datasets/short_video/QVID/videos/00000284.mp4"
cap = cv2.VideoCapture(video_path)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
cap.release()


keypoints = data['keypoints']  # Shape: (N_frames, 2, 133, 2)
scores = data['keypoint_scores']  # Shape: (N_frames, 2, 133)

x_coords = keypoints[..., 0]
y_coords = keypoints[..., 1]
x_norm = x_coords / width
y_norm = y_coords / height
normalized_keypoints = torch.stack([x_norm, y_norm], dim=-1)

dummy_person = (scores.sum(dim=-1) == 0.0) 
dummy_person = dummy_person.unsqueeze(-1).unsqueeze(-1)
normalized_keypoints = torch.where(entire_person_is_padded, torch.tensor(-1.0), normalized_keypoints)

print("Original shape:", normalized_data['keypoints_normalized'].shape)
print("Normalized Range Min/Max:", normalized_data['keypoints_normalized'].min().item(), normalized_data['keypoints_normalized'].max().item()
# Out:
#   Cell In[143], line 20
#     print("Normalized Range Min/Max:", normalized_data['keypoints_normalized'].min().item(), normalized_data['keypoints_normalized'].max().item()
#                                                                                                                                                  ^
# SyntaxError: incomplete input

# %%
video_path = "/home/stellasu/scratch/stellasu/long_video_datasets/short_video/QVID/videos/00000284.mp4"
fps = 1
max_frames = 16

cap = cv2.VideoCapture(video_path)
video_fps = cap.get(cv2.CAP_PROP_FPS) or 30.0
total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
stride = max(1.0, video_fps / fps)
indices: List[int] = []
pos = 0.0
while pos < total and len(indices) < max_frames:
    indices.append(min(round(pos), total - 1))
    pos += stride
if not indices:
    indices = [0]
indices = sorted(list(set(indices)))
cap.release()

# %%
video_path = "/home/stellasu/scratch/stellasu/long_video_datasets/short_video/QVID/videos/00000284.mp4"
cap = cv2.VideoCapture(video_path)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
cap.release()

# %%
width, height
# Out:
# (640.0, 360.0)
